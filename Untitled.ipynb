# %%
import numpy as np 
import matplotlib.pyplot as plt 
from scipy.stats import norm 
import statistics 
  
# Plot between -10 and 10 with .001 steps. 
x_axis = np.arange(-20, 20, 0.01) 
  
# Calculating mean and standard deviation 
mean = statistics.mean(x_axis) 
sd = statistics.stdev(x_axis) 
  
plt.plot(x_axis, norm.pdf(x_axis, mean, sd)) 
plt.show()

# %%
import numpy as np 
import matplotlib.pyplot as plt 
#from scipy.stats import norm 
import statistics 
  
# Plot between -10 and 10 with .001 steps. 
x_axis = np.arange(-0.01, 0.5, 0.0001) 
  
# Calculating mean and standard deviation 
mean = 0.235   
sd = 0.015
  
plt.plot(x_axis, norm.pdf(x_axis, mean, sd)) 
plt.show()

# %%
from scipy.stats import lognorm, norm
stddev = 0.235 
mean = 0.015
dist1=lognorm([stddev],loc=mean)
stddev = 1.070
mean =  0.047
dist2=lognorm([stddev],loc=mean)

# %%
import pylab as pl
x=np.linspace(0,3,200)
pl.title('PDFs of Pentagon and Interval runtime distribution')
pl.plot(x,dist1.pdf(x), label='Interval')
pl.plot(x,dist2.pdf(x), label='Pentagon')
pl.legend(loc='upper right')
plt.savefig("myImagePDF.pdf", format="pdf", dpi=300)

# %%
mean1 = 0.235 
stddev1= 0.015
dist1=norm(loc=mean1, scale=stddev1)

mean2 = 1.070
stddev2 =  0.047
dist2=norm(loc=mean2, scale=stddev2)
x=np.linspace(0.0,1.3,500)
pl.title('PDFs of Pentagon and Interval runtime distribution')
pl.plot(x,dist1.pdf(x), label='Interval')
pl.plot(x,dist2.pdf(x), label='Pentagon')
pl.legend(loc='upper right')
plt.savefig("myImagePDF.pdf", format="pdf", dpi=300)

# %%
stddev = 10**0.235 
mean = 10**0.015
dist1=lognorm([stddev],loc=mean)
stddev = 10**1.070
mean =  10**0.047
dist2=lognorm([stddev],loc=mean)
x=np.linspace(0.95,1.3,400)
pl.title('PDFs of Pentagon and Interval runtime distribution')
pl.plot(x,dist1.pdf(x), label='Interval')
pl.plot(x,dist2.pdf(x), label='Pentagon')
pl.legend(loc='upper right')
#plt.savefig("myImagePDF.pdf", format="pdf", dpi=300)

# %%
stddev_int = 0.074 
mean_int = 1.637
dist_int=lognorm([stddev],loc=mean)
stddev_pent = 40.97
mean_pent = 58.306
dist_pent=lognorm([stddev],loc=mean)
x=np.linspace(0,2.5,400)
p = lognorm.pdf(x = x, scale = mean_int, s = stddev_int)
p1 = lognorm.pdf(x = x, scale = mean_pent, s = stddev_pent)
pl.title('PDFs of Pentagon and Interval runtime distribution')
#pl.plot(x,dist_int.pdf(x), label='Interval')
#pl.plot(x,dist2.pdf(x), label='Pentagon')
pl.plot(x, p, label="Interval")
pl.plot(x, p1, label="Pentagon")
pl.legend(loc='upper right')
plt.savefig("myImagePDF1.pdf", format="pdf", dpi=300)

# %%
stddev_int = 0.074 
mean_int = 0.235
dist_int=lognorm([stddev],loc=mean)
stddev_pent = 10**1.070
mean_pent = 297743
dist_pent=lognorm([stddev],loc=mean)
x=np.linspace(0,3,400)
p = lognorm.pdf(x = x, scale = mean_int, s = stddev_int)
mean2 = 1.070
stddev2 =  0.047
p2 = lognorm.pdf(x = x, scale = mean2, s = stddev2)
pl.title('PDFs of Pentagon and Interval runtime distribution')
#pl.plot(x,dist_int.pdf(x), label='Interval')
#pl.plot(x,dist2.pdf(x), label='Pentagon')
pl.plot(x, p)
pl.plot(x, p2)
#pl.legend(loc='upper right')

# %%
stddev_int = 0.015
mean_int = 0.227
dist_int=lognorm([stddev],loc=mean)
stddev_pent = 0.042
mean_pent = 0.711
dist_pent=lognorm([stddev],loc=mean)
x=np.linspace(0,1,400)
p = lognorm.pdf(x = x, scale = mean_int, s = stddev_int)
mean2 = 1.070
stddev2 =  0.047
p2 = lognorm.pdf(x = x, scale = mean_pent, s = stddev_pent)
pl.title('PDFs of Pentagon and Interval runtime distribution')
#pl.plot(x,dist_int.pdf(x), label='Interval')
#pl.plot(x,dist2.pdf(x), label='Pentagon')
pl.plot(x, p)
pl.plot(x, p2)
#pl.legend(loc='upper right')

# %%
from scipy.stats import lognorm, norm
stddev =  0.015 
mean = 0.227
dist1=lognorm([stddev],loc=mean)
stddev = 0.042
mean =  0.711
dist2=lognorm([stddev],loc=mean)

# %%
x=np.linspace(0,3,400)

pl.title('PDFs of Pentagon and Interval runtime distribution')
pl.plot(x,dist1.pdf(x), label='Interval')
pl.plot(x,dist2.pdf(x), label='Pentagon')
pl.legend(loc='upper right')
#plt.savefig("myImagePDF.pdf", format="pdf", dpi=300)

# %%
stddev_int = 0.015 
mean_int = 0.227
dist_int=lognorm([stddev],loc=mean)
stddev_pent = 0.042
mean_pent = 0.711
dist_pent=lognorm([stddev],loc=mean)
x=np.linspace(0,2.5,400)
p = lognorm.pdf(x = x, scale = mean_int, s = stddev_int)
p1 = lognorm.pdf(x = x, scale = mean_pent, s = stddev_pent)
pl.title('PDFs of Pentagon and Interval runtime distribution')
#pl.plot(x,dist_int.pdf(x), label='Interval')
#pl.plot(x,dist2.pdf(x), label='Pentagon')
pl.plot(x, p, label="Interval")
pl.plot(x, p1, label="Pentagon")
pl.legend(loc='upper right')
plt.savefig("myImagePDF1.pdf", format="pdf", dpi=300)

# %%
stddev_int = 0.015 
mean_int = 0.227
dist_int=norm(loc=mean_int, scale=stddev_int)

stddev_pent = 0.042
mean_pent = 0.711
dist_pent=norm(loc=mean2, scale=stddev2)
x=np.linspace(0.0,1.3,500)
pl.title('PDFs of Pentagon and Interval runtime distribution')
pl.plot(x,dist_int.pdf(x), label='Interval')
pl.plot(x,dist_pent.pdf(x), label='Pentagon')
pl.legend(loc='upper right')
plt.savefig("myImagePDF.pdf", format="pdf", dpi=300)
